# %% [markdown]
# On utilise une approche encore plus forte d'apprentissage profond basée sur l'utilisation de réseaux de neurones récurrents. On suppose disposer d'un réseau déjà entrainé.

# %%
import matplotlib
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchtext
from torchtext.legacy.data import Field, TabularDataset, BucketIterator

import numpy as np
import pandas as pd
import os
import spacy
import string
import nltk
from nltk.corpus import stopwords
import re

# %%
def cleanup_text(texts):
    cleaned_text = []
    for text in texts:
      # remove multiple spaces
        
        # remove newline
        text = re.sub(r'\n', ' ', text)

        text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
        text = re.sub(r'#', '', text)
        text = re.sub(' +', ' ', text)

        text = re.sub(r'\d+', '', text)
        text = "".join([char.lower() for char in text if char not in string.punctuation]) 
        
        text = re.sub('\s+', ' ', text).strip()
        
        if text != '' and not text in stopwords.words("english"):
          cleaned_text.append(text)
    return cleaned_text

TEXT = Field(sequential=True, lower=True, include_lengths=False,
             batch_first = True, tokenize = str.split, preprocessing = cleanup_text)

SELECTED_TEXT = Field(sequential=True, batch_first = True, use_vocab = True, lower=True, 
                      tokenize = str.split, preprocessing = cleanup_text)


ID = Field(sequential=False, use_vocab = False, batch_first = True)

SENTIMENT = Field(sequential=False, use_vocab = True)

# %%
train_dataset = TabularDataset(
    format="csv", path= os.getcwd() + r"/donnees/train.csv",
    fields=[(None, None), ('text', TEXT), ('selected_text', SELECTED_TEXT), ('sentiment', SENTIMENT)]
)

# %%
TEXT.build_vocab(train_dataset, min_freq = 1, vectors = "glove.6B.100d")
SELECTED_TEXT.vocab = TEXT.vocab
SENTIMENT.build_vocab(train_dataset, min_freq = 1, vectors = "glove.6B.100d")

# %%
class LSTMModele(nn.Module):
  def __init__(self, emb_dim = 100):
    super(LSTMModele, self).__init__()
    self.embeddings = nn.Embedding.from_pretrained(TEXT.vocab.vectors, freeze = False)
    self.lstm = nn.LSTM(input_size = emb_dim, hidden_size = emb_dim, batch_first = True, num_layers=1)
    self.fc1 = nn.Linear(emb_dim, 1)
    #self.act = nn.ReLU()
    #self.fc2 = nn.Linear(50, 1)

  def forward(self, inputs):
    embeds = self.embeddings(inputs)
    x, (h_n, c_n) = self.lstm(embeds)
    x = self.fc1(x)
    #x = self.act(x)
    #x = self.fc2(x)
    #print(x.shape)
    return torch.squeeze(x)

# %%
device = 'cpu'

# %%
model = LSTMModele()
model.load_state_dict(torch.load("Model-emb100-fc100_1", map_location=torch.device('cpu')))
model.eval()
# Out:
# LSTMModele(
#   (embeddings): Embedding(26685, 100)
#   (lstm): LSTM(100, 100, batch_first=True)
#   (fc1): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
def extract_word(sentence, net, device):
    conv = []
    sentence = str.split(sentence)
    sentence = cleanup_text(sentence)
    #print(sentence)
    for word in sentence:
        conv.append(TEXT.vocab.stoi[word])

    sentence_tensor = torch.tensor([conv]).to(device)
    res = net(sentence_tensor)
    sentence_tensor = torch.squeeze(sentence_tensor)
    compteur = 0
    for i in iter(res):
        if round(float(i)) == 1:
            #print("Extraction :  ", sentence[compteur])
            yield sentence[compteur]
        compteur = compteur+1
        
def extraction_list(sentence):
    if sentence == "":
        return []
    return [word for word in extract_word(sentence, model, 'cpu')

# %%
for k in extract_word("awesome", model, 'cpu'):
    print(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-915410272324> in <module>
# ----> 1 for k in extract_word("awesome", model, 'cpu'):
#       2     print(k)
#
# <ipython-input-103-952857b33ae3> in extract_word(sentence, net, device)
#      11     sentence_tensor = torch.squeeze(sentence_tensor)
#      12     compteur = 0
# ---> 13     for i in iter(res):
#      14         if round(float(i)) == 1:
#      15             #print("Extraction :  ", sentence[compteur])
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/tensor.py in __iter__(self)
#     583             return handle_torch_function(Tensor.__iter__, (self,), self)
#     584         if self.dim() == 0:
# --> 585             raise TypeError('iteration over a 0-d tensor')
#     586         if torch._C._get_tracing_state():
#     587             warnings.warn('Iterating over a tensor might cause the trace to be incorrect. '
#
# TypeError: iteration over a 0-d tensor

# %%
def jaccard(str1, str2): 
    try:
        a = set(str1.lower().split())
        b = set(str2.lower().split())
        c = a.intersection(b)
        return float(len(c)) / (len(a) + len(b) - len(c))
    except:
        print(str1, str2)

def merge(L,i=0,j=None):
    """Creates sentences from lists of words."""
    if L == []:
        return ""
    if j is None:
        j = len(L)
    acc = L[i]
    for k in range(i+1,j):
        acc = acc + " " + L[k]
    return acc

def extract_closest_substring(str1, str2, score_fonc = jaccard ):
    """Extracts from str1 closest substring to str2 with respect to Jaccard distance."""
    """ /!\ Not optimal /!\ """
    split1 = str1.split(" ")
    N = len(split1)
    maxa = 0
    stra = str1
    for i in range(N):
        for j in range(i, N+1):
            acc = merge(split1,i,j)
            jacc = score_fonc(acc, str2)
            if acc != "" and jacc >= maxa:
                maxa = jacc
                stra = acc
    return stra

str1 = "Dans le concours, la métrique à utiliser est le score de Jaccard"
str2 = "La métrique est l'étude des objets métriques"

print(jaccard(str1,str2))
extract_closest_substring(str2, str1)
# Out:
# 0.2
# 'La métrique est'

# %%
def row_fuse_and_extr(row):
    try:
        return extract_closest_substring(row.text, merge(extraction_list(row.text)))
    except :
        return row.text

class SmartClassifier():
    def __init__(self):
        return
    
    def sign_run(self,test_frame,sign):
        """Does a branch run"""
        if sign == "neutral":
            #neutral tweets return tweet itself
            aux = test_frame[test_frame.sentiment == sign]
            aux["selected_text"] = aux.text
            return aux.loc[:,["textID", "text", "selected_text", "sentiment"]]
        
        aux = test_frame
        aux["selected_text"] = aux.apply(row_fuse_and_extr, axis = 1)
                
        return aux.loc[:,["textID","text","selected_text","sentiment"]]
    
    def __call__(self, test_frame):
        """Runs the actual calculation"""
        acc_pos = self.sign_run(test_frame, "positive")
        acc_neg = self.sign_run(test_frame, "negative")
        acc_neu = self.sign_run(test_frame, "neutral")
        
        return pd.concat([acc_pos, acc_neg, acc_neu])

# %%
#Examples
R = SmartClassifier()
KK = R(test_set)
KK = KK.sort_index()
KK

# %%
p = 100
KK[KK.sentiment == "positive"].iloc[p:p+50,:]
# Out:
#          textID                                               text  \
# 161  c7240790da   Aren`t you suppossed to support the local eco...
# 161  c7240790da   Aren`t you suppossed to support the local eco...
# 162  08ede23635                              good to know   thanks
# 162  08ede23635                              good to know   thanks
# 166  e34af4fd97   E.L.O.  wow, brings back so many happy memori...
# 166  e34af4fd97   E.L.O.  wow, brings back so many happy memori...
# 167  0e8aa10a4e   that`s a very cute picture ... but you don`t ...
# 167  0e8aa10a4e   that`s a very cute picture ... but you don`t ...
# 168  29148dc95c   oh i love sunday mornings like this - mum jus...
# 168  29148dc95c   oh i love sunday mornings like this - mum jus...
# 175  4ea7102112                    _chick haha. I completely agree
# 175  4ea7102112                    _chick haha. I completely agree
# 178  cdd172d6a7  Going to bed after a great night with a friend...
# 178  cdd172d6a7  Going to bed after a great night with a friend...
# 180  799e17e7a7  it`s nice to leave the office when the sun is ...
# 180  799e17e7a7  it`s nice to leave the office when the sun is ...
# 193  e4ad1684bb   glad to know that the ad display problem was ...
# 193  e4ad1684bb   glad to know that the ad display problem was ...
# 194  f7835156a5                                              woot!
# 194  f7835156a5                                              woot!
# 198  be9ed19513  Happy #StarWarsDay. May the 4th be with you!  ...
# 198  be9ed19513  Happy #StarWarsDay. May the 4th be with you!  ...
# 209  96ec2855e4   Panchito`s burfday party tonight... wish you ...
# 209  96ec2855e4   Panchito`s burfday party tonight... wish you ...
# 212  fc49e426f5                the best things in life are free  x
# 212  fc49e426f5                the best things in life are free  x
# 213  a172818c9e  misses my Mom today. She was my Best Friend an...
# 213  a172818c9e  misses my Mom today. She was my Best Friend an...
# 218  e6e02e1be6  Be sure to let the moms you know how fabulous ...
# 218  e6e02e1be6  Be sure to let the moms you know how fabulous ...
# 221  f3ec0395b0    it`s very pleasant. i sooo rarely just have ...
# 221  f3ec0395b0    it`s very pleasant. i sooo rarely just have ...
# 222  37ffa83550   thank you!! ooh I see you`ve read Desert Isla...
# 222  37ffa83550   thank you!! ooh I see you`ve read Desert Isla...
# 223  cb8c730261                        __O lol but tiz a good song
# 223  cb8c730261                        __O lol but tiz a good song
# 227  7ab82d9fda  _Wright THANK YOU! 'Return of the Mack' is THE...
# 227  7ab82d9fda  _Wright THANK YOU! 'Return of the Mack' is THE...
# 230  6cd35dd82e   I do my humble best  Going on a works paintba...
# 230  6cd35dd82e   I do my humble best  Going on a works paintba...
# 232  9fae9e3145  _Morden ..be at richard`s. if not then i`ll se...
# 232  9fae9e3145  _Morden ..be at richard`s. if not then i`ll se...
# 235  bd8ba2ad7e    And I just love every little thing about you...
# 235  bd8ba2ad7e    And I just love every little thing about you...
# 238  044f146e5c  Had an amazing night with my favorite lady friend
# 238  044f146e5c  Had an amazing night with my favorite lady friend
# 240  abda0ac082  is fixin to clean the house for my mom for mot...
# 240  abda0ac082  is fixin to clean the house for my mom for mot...
# 244  f43efa3560  MY SiSTER iN LAW JUST LEFT FOR HER PROM!! SHE ...
# 244  f43efa3560  MY SiSTER iN LAW JUST LEFT FOR HER PROM!! SHE ...
#
#                                          selected_text sentiment
# 161                                               good  positive
# 161                                               good  positive
# 162                                     good to know    positive
# 162                                     good to know    positive
# 166                          brings back so many happy  positive
# 166                          brings back so many happy  positive
# 167                                               cute  positive
# 167                                               cute  positive
# 168                                               love  positive
# 168                                               love  positive
# 175                                   completely agree  positive
# 175                                   completely agree  positive
# 178            great night with a friend  glad to know  positive
# 178            great night with a friend  glad to know  positive
# 180                                               nice  positive
# 180                                               nice  positive
# 193                                       glad to know  positive
# 193                                       glad to know  positive
# 194                                              woot!  positive
# 194                                              woot!  positive
# 198                                              Happy  positive
# 198                                              Happy  positive
# 209                              party tonight... wish  positive
# 209                              party tonight... wish  positive
# 212                                               best  positive
# 212                                               best  positive
# 213  Best Friend and even though she has been gone ...  positive
# 213  Best Friend and even though she has been gone ...  positive
# 218                                           fabulous  positive
# 218                                           fabulous  positive
# 221                         sooo rarely just have time  positive
# 221                         sooo rarely just have time  positive
# 222                                              thank  positive
# 222                                              thank  positive
# 223                                               song  positive
# 223                                               song  positive
# 227                                              THANK  positive
# 227                                              THANK  positive
# 230                                              doubt  positive
# 230                                              doubt  positive
# 232                                                get  positive
# 232                                                get  positive
# 235                                               love  positive
# 235                                               love  positive
# 238                                      amazing night  positive
# 238                                      amazing night  positive
# 240        clean the house for my mom for mother`s day  positive
# 240        clean the house for my mom for mother`s day  positive
# 244                                             AROUND  positive
# 244                                             AROUND  positive

# %%
KK.loc[244,:].text.iloc[0]
# Out:
# 'MY SiSTER iN LAW JUST LEFT FOR HER PROM!! SHE LOOKED SOO PRETTY.. TEARS ALL AROUND'

# %%
# Load the dataset
train_set = pd.read_csv(r"train.csv")
test_set = pd.read_csv(r"test.csv")

#print(train_set.shape)    => (27481, 4)  (textID, text, selected_text, sentiment )
#print(test_set.shape)     => (3534, 3)   (textID, text, sentiment)

train_data_text = train_set["text"]
train_data_sentiment = train_set["sentiment"]

N_train = train_data_text.shape[0]

train_data = [(train_data_text[k],train_data_sentiment[k]) for k in range(N_train)]
train_labels = train_set["selected_text"]


# check data makes sense

print("Exemple 1 :",train_data[1], "extrait choisi :", train_labels[1])
print("Exemple 2 :",train_data[59], "extrait choisi :", train_labels[59])
print("Exemple 3 :",train_data[750], "extrait choisi :", train_labels[750])
# Out:
# Exemple 1 : (' Sooo SAD I will miss you here in San Diego!!!', 'negative') extrait choisi : Sooo SAD
# Exemple 2 : (' what fun are you speaking of?', 'neutral') extrait choisi : what fun are you speaking of?
# Exemple 3 : (' Thanks! Welcome back!', 'positive') extrait choisi : Thanks! Welcome back!

# %%
aux2 = aux[aux.ouss == 0].loc[:, ["sentiment","text","ouss"]]

# %%
p = 0
aux2.iloc[p:p+50,:]
# Out:
#      sentiment                                     text ouss
# 4     positive   http://twitpic.com/4w75p - I like it!!    0
# 16    negative                                 Miss you    0
# 17    negative                             Cramps . . .    0
# 49    negative                                Not happy    0
# 92     neutral                                Yes, I am    0
# 106    neutral                                 yeh me 2    0
# 130   positive                                 Welcome!    0
# 135   negative                     Now I have a sunburn    0
# 170    neutral      is ONLiNE  http://plurk.com/p/stjdg    0
# 194   positive                                    woot!    0
# 196    neutral      ???    ?????? - http://bit.ly/nAcK2    0
# 215   negative                         that is a bummer    0
# 245    neutral                            follow me too    0
# 248   positive                              , goodnight    0
# 295   positive                            its hilarious    0
# 363    neutral                                  me too.    0
# 370   negative                            i am so sorry    0
# 375   negative                                So tired.    0
# 414   positive             Nice!!!!!!!! I WILL be there    0
# 420    neutral                           is on facebook    0
# 433   positive                           I sure she can    0
# 462   positive                        Fun is being had.    0
# 477    neutral                  Speaking,,,Speaking ...    0
# 565    neutral                                 _eat_out    0
# 648    neutral                                    quite    0
# 664    neutral                            Raining again    0
# 696    neutral                                  me tooo    0
# 706   positive                                  awesome    0
# 761    neutral                          where is home??    0
# 773    neutral                              out to play    0
# 814    neutral                whatever will be, will be    0
# 825    neutral                           We are working    0
# 838    neutral                                 Memories    0
# 889   negative                            _ that sucks!    0
# 890   positive                              yes it does    0
# 912    neutral                                  me too!    0
# 920    neutral                              6 am.  you?    0
# 960   negative                                oh ****!!    0
# 974    neutral                                --Nothing    0
# 988   positive    is excited!  http://plurk.com/p/stk04    0
# 1022  negative                 It`s already over? ****!    0
# 1138   neutral        Thanks    ? http://blip.fm/~5z6n8    0
# 1153  negative                       how crappy for him    0
# 1200   neutral                                 together    0
# 1228   neutral                                  Will do    0
# 1283   neutral                             How are you?    0
# 1309   neutral                                   i cant    0
# 1327   neutral                                  will do    0
# 1353  positive                                  welcome    0
# 1369   neutral                        Is twubbing again    0
